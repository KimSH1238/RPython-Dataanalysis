# %%
a="Life is too short, ton need Python"
print(a[3])
print(a[0:4])
print(a[-1])
# Out:
# e
# Life
# n

# %%
a="20010331Rainy"
date=a[:8]
year=a[:4]
day=a[4:8]
weather=a[8:]
print(date)
print(year)
print(day)
print(weather)
# Out:
# 20010331
# 2001
# 0331
# Rainy

# %%
number=3
print("I ate %d apples." %number)
"I ate %d apples." %number
# Out:
# I ate 3 apples.
# 'I ate 3 apples.'

# %%
number="three"
print("I ate %s apples." %number)
"I ate %s apples." %number
# Out:
# I ate three apples.
# 'I ate three apples.'

# %%
#숫자 바로 대입하기
print("I ate {0} apples".format(3))
"I ate {0} apples".format(3)
# Out:
# I ate 3 apples
# 'I ate 3 apples'

# %%
#문자열 바로 대입하기
print("I ate {0} apples".format("five"))
"I ate {0} apples".format("five")
# Out:
# I ate five apples
# 'I ate five apples'

# %%
#2개 이상의 값 넣기
number=10
day="three"
print("I ate {0} apples. So i was sick for {1} days".format(number, day))
"I ate {0} apples. So i was sick for {1} days".format(number, day)
# Out:
# I ate 10 apples. So i was sick for three days
# 'I ate 10 apples. So i was sick for three days'

# %%
day*2
# Out:
# 'threethree'

# %%
#문자열곱하기 응용 __multistring.py
print("="*50)
print("My programme")
print("="*50)
# Out:
# ...
# My programme
# ...
